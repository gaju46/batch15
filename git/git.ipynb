# %% [markdown]
# ## workingdir ------ >staging/temporary area--->remote repository
# ## git add .....>git commit -m "message"....>git origin master

# %%
# how to write commit messgae in a better way
# feat : add login page 
# fix : bug fix in login page
# docs : update readme file
# style : code formating
# refactor : code refactoring
# test : add test cases
